# %%
import pandas as pd
import numpy as np

# %%
location = "DC_Properties.csv"
df = pd.read_csv(location)
df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# ...

# %%
df.head(5)
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0   ...    -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0   ...    -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0   ...    -77.039361       Old City 2   040 D Old City 2
#
# ...

# %%
df.tail(5)
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 158952      158952       1          0  Forced Air  Y        NaN      3      1
# 158953      158953       1          0  Forced Air  Y        NaN      4      2
# 158954      158954       2          0  Forced Air  Y        NaN      4      2
# 158955      158955       1          0   Warm Cool  Y        NaN      2      0
# 158956      158956       1          0   Warm Cool  Y        NaN      2      0
#
#            AYB  YR_RMDL   ...     LONGITUDE       ASSESSMENT_NBHD  \
# 158952  1938.0   2006.0   ...     -77.01942            Old City 2
# 158953  1938.0   2006.0   ...     -77.01942            Old City 2
# 158954  1920.0   2007.0   ...     -77.01942            Old City 2
# 158955  1965.0      NaN   ...     -77.01823  Southwest Waterfront
# 158956  1965.0      NaN   ...     -77.01823  Southwest Waterfront
#
#        ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# BATHRM                  int64
# HF_BATHRM               int64
# HEAT                   object
# AC                     object
# NUM_UNITS             float64
# ROOMS                   int64
# BEDRM                   int64
# AYB                   float64
# YR_RMDL               float64
# EYB                     int64
# STORIES               float64
# SALEDATE               object
# PRICE                 float64
# QUALIFIED              object
# SALE_NUM                int64
# GBA                   float64
# BLDG_NUM                int64
# STYLE                  object
# STRUCT                 object
# GRADE                  object
# CNDTN                  object
# EXTWALL                object
# ROOF                   object
# INTWALL                object
# KITCHENS              float64
# FIREPLACES              int64
# USECODE                 int64
# LANDAREA                int64
# GIS_LAST_MOD_DTTM      object
# SOURCE                 object
# ...

# %%
df['BATHRM'].max()
# Out:
# 14

# %%
df['HF_BATHRM'].max()
# Out:
# 11

# %%
df['PRICE'].max()
# Out:
# 137427545.0

# %%
df['PRICE'].min()
# Out:
# 1.0

# %%
len(df) 
#to count how many rows it has
# Out:
# 158957

# %%
df2= df[['BEDRM','BATHRM','GBA','PRICE','WARD','QUADRANT','STYLE','SALEDATE','KITCHENS','AYB','FULLADDRESS']]

# %%
df2.head()
# Out:
#    BEDRM  BATHRM     GBA      PRICE    WARD QUADRANT    STYLE  \
# 0      4       4  2522.0  1095000.0  Ward 2       NW  3 Story
# 1      5       3  2567.0        NaN  Ward 2       NW  3 Story
# 2      5       3  2522.0  2100000.0  Ward 2       NW  3 Story
# 3      5       3  2484.0  1602000.0  Ward 2       NW  3 Story
# 4      3       2  5255.0        NaN  Ward 2       NW  3 Story
#
#               SALEDATE  KITCHENS     AYB                   FULLADDRESS
# 0  2003-11-25 00:00:00       2.0  1910.0          1748 SWANN STREET NW
# 1  2000-08-17 00:00:00       2.0  1898.0          1746 SWANN STREET NW
# 2  2016-06-21 00:00:00       2.0  1910.0          1744 SWANN STREET NW
# 3  2006-07-12 00:00:00       2.0  1900.0          1742 SWANN STREET NW
# 4                  NaN       1.0  1913.0  1804 NEW HAMPSHIRE AVENUE NW

# %%
dupe=df2.duplicated()

# %%
df2.drop_duplicates()
#drops duplicate data
# Out:
#         BEDRM  BATHRM     GBA      PRICE    WARD QUADRANT    STYLE  \
# 0           4       4  2522.0  1095000.0  Ward 2       NW  3 Story
# 1           5       3  2567.0        NaN  Ward 2       NW  3 Story
# 2           5       3  2522.0  2100000.0  Ward 2       NW  3 Story
# 3           5       3  2484.0  1602000.0  Ward 2       NW  3 Story
# 4           3       2  5255.0        NaN  Ward 2       NW  3 Story
# 5           5       3  5344.0  1950000.0  Ward 2       NW  4 Story
# 6           2       1  1260.0        NaN  Ward 2       NW  2 Story
# 7           4       3  2401.0  1050000.0  Ward 2       NW  3 Story
# 8           3       3  1488.0  1430000.0  Ward 2       NW  2 Story
# 9           2       1  1590.0        NaN  Ward 2       NW  2 Story
# 10          5       3  2748.0        NaN  Ward 2       NW  3 Story
# 11          6       5  3100.0        NaN  Ward 2       NW  3 Story
# 12          5       2  3119.0        NaN  Ward 2       NW  3 Story
# ...

# %%
df2.describe()
# Out:
#                BEDRM         BATHRM            GBA         PRICE  \
# count  158957.000000  158957.000000  106696.000000  9.821600e+04
# mean        2.732506       1.810678    1714.539889  9.313516e+05
# std         1.358864       0.976396     880.677860  7.061325e+06
# min         0.000000       0.000000       0.000000  1.000000e+00
# 25%         2.000000       1.000000    1190.000000  2.400000e+05
# 50%         3.000000       2.000000    1480.000000  3.999990e+05
# 75%         3.000000       2.000000    1966.000000  6.520000e+05
# max        24.000000      14.000000   45384.000000  1.374275e+08
#
#             KITCHENS            AYB
# count  106695.000000  158686.000000
# mean        1.219251    1941.987579
# std         0.621170      33.640234
# min         0.000000    1754.000000
# 25%         1.000000    1918.000000
# 50%         1.000000    1937.000000
# 75%         1.000000    1960.000000
# max        44.000000    2019.000000

# %%
df2.groupby("WARD")

# %%
df2[["PRICE","BEDRM"]].groupby(df2["WARD"]).min()
# Out:
#         PRICE  BEDRM
# WARD
# Ward 1   10.0      0
# Ward 2   10.0      0
# Ward 3    1.0      0
# Ward 4  250.0      0
# Ward 5    1.0      0
# Ward 6    1.0      0
# Ward 7   10.0      0
# Ward 8    1.0      0

# %%
df2[["PRICE","BEDRM"]].groupby(df2["WARD"]).max()
# Out:
#               PRICE  BEDRM
# WARD
# Ward 1   12780000.0     20
# Ward 2   53969391.0     19
# Ward 3  137427545.0     16
# Ward 4    5000000.0     24
# Ward 5    5250000.0     14
# Ward 6   11000000.0     12
# Ward 7   11000000.0     12
# Ward 8   25100000.0     13

# %%
df2[["PRICE","BEDRM"]].groupby(df2["WARD"]).median()
# Out:
#            PRICE  BEDRM
# WARD
# Ward 1  461500.0      2
# Ward 2  475000.0      2
# Ward 3  600000.0      3
# Ward 4  428000.0      3
# Ward 5  360710.0      3
# Ward 6  469900.0      3
# Ward 7  200000.0      3
# Ward 8  194900.0      3

# %%
df2 = df2.dropna() #drop the missing data

# %%
df2.isnull().sum()#to check how many rows have missing data
# Out:
# BEDRM          0
# BATHRM         0
# GBA            0
# PRICE          0
# WARD           0
# QUADRANT       0
# STYLE          0
# SALEDATE       0
# KITCHENS       0
# AYB            0
# FULLADDRESS    0
# dtype: int64

# %%
df3=df[["PRICE","WARD","BEDRM"]]
df3.head()
# Out:
#        PRICE    WARD  BEDRM
# 0  1095000.0  Ward 2      4
# 1        NaN  Ward 2      5
# 2  2100000.0  Ward 2      5
# 3  1602000.0  Ward 2      5
# 4        NaN  Ward 2      3

# %%
df3_no_missing = df3.dropna()
#drop the missing data

# %%
df3.isnull().sum()
#to check how many rows have missing data
# Out:
# PRICE    60741
# WARD         1
# BEDRM        0
# dtype: int64

# %%
df3_no_missing.isnull().sum()
#to verify there is no more missing data
# Out:
# PRICE    0
# WARD     0
# BEDRM    0
# dtype: int64

# %%
len(df3)
#how many rows it had
# Out:
# 158957

# %%
len(df3_no_missing)
#how many rows it hows now
# Out:
# 98216

# %%
ward1df= df3_no_missing.loc[df3_no_missing["WARD"]=="Ward 1"]
ward1df.head()
# Out:
#         PRICE    WARD  BEDRM
# 156  200000.0  Ward 1      3
# 157  650000.0  Ward 1      3
# 158  660000.0  Ward 1      1
# 160  830000.0  Ward 1      3
# 161  635000.0  Ward 1      3

# %%
ward1df['PRICE'].max()
# Out:
# 12780000.0

# %%
ward1df['PRICE'].min()
# Out:
# 10.0

# %%
df4= df[['BEDRM','PRICE','QUADRANT']]
df4.head()
# Out:
#    BEDRM      PRICE QUADRANT
# 0      4  1095000.0       NW
# 1      5        NaN       NW
# 2      5  2100000.0       NW
# 3      5  1602000.0       NW
# 4      3        NaN       NW

# %%
df4= df4.dropna()

# %%
df4.groupby(['PRICE','QUADRANT']).mean()
# Out:
#                           BEDRM
# PRICE       QUADRANT
# 1.0         NE         3.000000
#             NW         2.000000
#             SW         6.000000
# 10.0        NE         2.500000
#             NW         3.000000
# 250.0       NE         3.000000
#             NW         4.000000
#             SE         2.666667
# 500.0       NW         4.250000
# 936.0       NW         4.000000
# 1000.0      NE         3.000000
#             NW         0.500000
#             SE         4.000000
# 1377.0      NW         3.000000
# 2000.0      NW         0.000000
#             SE         3.000000
# 3000.0      NE         3.000000
#             NW         2.000000
# 3270.0      NW         1.000000
# 3523.0      SW         1.000000
# 3997.0      SE         3.000000
# 4101.0      SE         4.000000
# 4156.0      NW         4.000000
# 4500.0      NW         3.000000
# 4850.0      SE         3.000000
# 5000.0      NE         3.500000
#             NW         3.000000
# ...

# %%
df2.drop_duplicates()
# Out:
#         BEDRM  BATHRM     GBA      PRICE    WARD QUADRANT            STYLE  \
# 0           4       4  2522.0  1095000.0  Ward 2       NW          3 Story
# 2           5       3  2522.0  2100000.0  Ward 2       NW          3 Story
# 3           5       3  2484.0  1602000.0  Ward 2       NW          3 Story
# 5           5       3  5344.0  1950000.0  Ward 2       NW          4 Story
# 7           4       3  2401.0  1050000.0  Ward 2       NW          3 Story
# 8           3       3  1488.0  1430000.0  Ward 2       NW          2 Story
# 14          3       3  2692.0  1325000.0  Ward 2       NW          2 Story
# 16          3       3  1662.0  1240000.0  Ward 2       NW          2 Story
# 19          3       3  1598.0   592250.0  Ward 2       NW          2 Story
# 20          5       3  3465.0    33232.0  Ward 2       NW          3 Story
# 22          3       1  1790.0   907400.0  Ward 2       NW          2 Story
# ...

# %%
df4["PRICE"].dtypes
# Out:
# dtype('float64')

# %%
bins= [0,100000,200000,300000,400000,500000,600000,800000,900000,1000000,2000000,50000000]
group_names= ['extremly low', 'very low','low','high low','low average','average','high average','low high','high','very high','extremly high']
df4["Range"] = pd.cut(df['PRICE'], bins, labels=group_names)
df4.head(100)
# Out:
#      BEDRM      PRICE QUADRANT          Range
# 0        4  1095000.0       NW      very high
# 2        5  2100000.0       NW  extremly high
# 3        5  1602000.0       NW      very high
# 5        5  1950000.0       NW      very high
# 7        4  1050000.0       NW      very high
# 8        3  1430000.0       NW      very high
# 14       3  1325000.0       NW      very high
# 16       3  1240000.0       NW      very high
# 19       3   592250.0       NW        average
# 20       5    33232.0       NW   extremly low
# 22       3   907400.0       NW           high
# 23       3  1065000.0       NW      very high
# 24       3  1100000.0       NW      very high
# 25       4    20000.0       NW   extremly low
# 27       3   703700.0       NW   high average
# 29       3  1210000.0       NW      very high
# 32       2   130500.0       NW       very low
# 37       4   339500.0       NW       high low
# 40       4  1050000.0       NW      very high
# ...

# %%
bins= [0,100000,200000,300000,400000,500000,600000,700000,800000,900000,1000000,137427545]
group_names= ['extremly low', 'very low','low','high low','low average','average','high average','low high','high','very high','extremly high']
ward1df["Range"] = pd.cut(df['PRICE'], bins, labels=group_names)
ward1df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         PRICE    WARD  BEDRM         Range
# 156  200000.0  Ward 1      3      very low
# 157  650000.0  Ward 1      3  high average
# 158  660000.0  Ward 1      1  high average
# 160  830000.0  Ward 1      3          high
# 161  635000.0  Ward 1      3  high average

# %%
ward1df['PRICE'].mean()
# Out:
# 573836.3117143086

# %%
ward2df= df3_no_missing.loc[df3_no_missing["WARD"]=="Ward 2"]
ward2df.head()
# Out:
#        PRICE    WARD  BEDRM
# 0  1095000.0  Ward 2      4
# 2  2100000.0  Ward 2      5
# 3  1602000.0  Ward 2      5
# 5  1950000.0  Ward 2      5
# 7  1050000.0  Ward 2      4

# %%
bins= [0,100000,500000,1000000,1500000,2000000,2500000,3000000,3500000,4000000,45000000,50000000]
group_names= ['extremly low', 'very low','low','high low','low average','average','high average','low high','high','very high','extremly high']
ward2df["Range"] = pd.cut(df['PRICE'], bins, labels=group_names)
ward2df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        PRICE    WARD  BEDRM        Range
# 0  1095000.0  Ward 2      4     high low
# 2  2100000.0  Ward 2      5      average
# 3  1602000.0  Ward 2      5  low average
# 5  1950000.0  Ward 2      5  low average
# 7  1050000.0  Ward 2      4     high low

# %%
ward2df["PRICE"].mean()
# Out:
# 1098570.4294727354

# %%
ward3df= df3_no_missing.loc[df3_no_missing["WARD"]=="Ward 3"]
ward3df.head()
# Out:
#           PRICE    WARD  BEDRM
# 20369  684500.0  Ward 3      3
# 20370  880000.0  Ward 3      4
# 20371  895000.0  Ward 3      4
# 20372  772500.0  Ward 3      4
# 20373  925000.0  Ward 3      3

# %%
ward3df["PRICE"].mean()
#Very high averaged priced homes
# Out:
# 3077715.8967103427

# %%
ward4df= df3_no_missing.loc[df3_no_missing["WARD"]=="Ward 4"]
ward4df.head()
# Out:
#            PRICE    WARD  BEDRM
# 31999   300500.0  Ward 4      3
# 32001   561000.0  Ward 4      3
# 32003   810000.0  Ward 4      3
# 32006   905000.0  Ward 4      3
# 32007  1112500.0  Ward 4      4

# %%
ward4df["PRICE"].mean()
# Out:
# 489922.4055384102

# %%
ward5df= df3_no_missing.loc[df3_no_missing["WARD"]=="Ward 5"]
ward5df.head()
# Out:
#          PRICE    WARD  BEDRM
# 1710  514000.0  Ward 5      4
# 1875  289500.0  Ward 5      4
# 1876  725000.0  Ward 5      6
# 1878  750000.0  Ward 5      8
# 1879  410000.0  Ward 5      4

# %%
ward5df["PRICE"].mean()
# Out:
# 395243.22666005127

# %%
ward6df= df3_no_missing.loc[df3_no_missing["WARD"]=="Ward 6"]
ward6df.head()
# Out:
#           PRICE    WARD  BEDRM
# 996    575000.0  Ward 6      3
# 997    737500.0  Ward 6      2
# 999    114000.0  Ward 6      3
# 1000  1200000.0  Ward 6      4
# 1001    77000.0  Ward 6      2

# %%
ward6df["PRICE"].mean()
# Out:
# 526868.4370657321

# %%
ward7df= df3_no_missing.loc[df3_no_missing["WARD"]=="Ward 7"]
ward7df.head()
# Out:
#           PRICE    WARD  BEDRM
# 80108   79900.0  Ward 7      3
# 80109   35000.0  Ward 7      3
# 80245  235000.0  Ward 7      2
# 80248  648000.0  Ward 7      3
# 80250  465000.0  Ward 7      3

# %%
ward7df["PRICE"].mean() 
#significantly lower mean for priced homes
# Out:
# 233922.17604336044

# %%
ward8df= df3_no_missing.loc[df3_no_missing["WARD"]=="Ward 8"]
ward8df.head()
# Out:
#           PRICE    WARD  BEDRM
# 92937   99700.0  Ward 8      3
# 92938  246000.0  Ward 8      4
# 92941  232289.0  Ward 8      5
# 92942  167500.0  Ward 8      2
# 92943  310000.0  Ward 8      3

# %%
ward8df["PRICE"].mean()
##significantly lower mean for priced homes
# Out:
# 271522.4439133206

# %%
pd.pivot_table(df2,index=["BEDRM"], values=["PRICE"],columns=["WARD"],aggfunc=[np.mean],fill_value=0).round()
# Out:
#             mean                                                         \
#            PRICE
# WARD      Ward 1      Ward 2     Ward 3    Ward 4     Ward 5     Ward 6
# BEDRM
# 0       325833.0   3587500.0  2191180.0  316700.0   319837.0  1350413.0
# 1       399136.0    794495.0   868143.0  320533.0   211724.0   345632.0
# 2       469843.0    776703.0   641659.0  315698.0   296713.0   482571.0
# 3       500683.0   1030323.0   740701.0  417701.0   381470.0   568145.0
# 4       637164.0   1390040.0   973544.0  582640.0   478755.0   722511.0
# 5       781456.0   1728696.0  1418279.0  751978.0   575489.0   864958.0
# 6       842401.0   2259336.0  1939125.0  817773.0   546544.0   883375.0
# 7       907553.0   2486571.0  2706960.0  887765.0   623350.0   994973.0
# 8       819119.0   2883506.0  2587662.0  502610.0   412719.0   573041.0
# 9      1037317.0   6007558.0  4422222.0  791036.0   335000.0   653279.0
# 10      918000.0    843000.0  1297000.0       0.0   350000.0   921250.0
# ...
